# %%
if True:
    print(1)
    print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
if False:
    print(1)
    print(2)
print(3)
# Out:
# 3

# %%
#list 
grocery_list = ["apple","banana",1]
grocery_list
# Out:
# ['apple', 'banana', 1]

# %%
grocery_list.append("fruits")
grocery_list
# Out:
# ['apple', 'banana', 1, 'fruits']

# %%
for i in grocery_list:
    print(i)
# Out:
# apple
# banana
# 1
# fruits

# %%
grocery_list[0]
# Out:
# 'apple'

# %%
grocery_list[:2]
# Out:
# ['apple', 'banana']

# %%
for i in range(4):
    print(grocery_list[i])
# Out:
# apple
# banana
# 1
# fruits

# %%
for i ,item in enumerate(grocery_list):
    print(i,item)
# Out:
# 0 apple
# 1 banana
# 2 1
# 3 fruits

# %%
j = len(grocery_list)-1
while j>=0:
    print(grocery_list[j])
    j -= 1
print("end")
# Out:
# fruits
# 1
# banana
# apple
# end

# %%
i = 0 
while i <= len(grocery_list)-1:
    print(grocery_list[i])
    i += 1
# Out:
# apple
# banana
# 1
# fruits

# %%
# or
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
# And
True and True
# Out:
# True

# %%
(3>2) and (4>5)
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False
